# %%
#loading dataframe libraries
import pandas as pd
#loading algebra libraries
import numpy as np
#loading visualization libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#loading warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#loading census income dataset
cust=pd.read_excel(r"C:\Users\hp\Desktop\Copy of customer_retention_dataset.xlsx")

# %%
cust
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
#chcking the columns
cust.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
cust.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
#checking the shape
cust.shape
# Out:
# (269, 71)

# %%
#chcking the datatypes
cust.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
#checking the dataset informaion
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
#checking the missing value
cust.isnull().values.any()
# Out:
# False

# %%
cust.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %% [markdown]
# ### There is no missing value in this dataset.

# %%
#printing there object type and their unique code
for column in cust.columns:
    if cust[column].dtypes==object:
        print(str(column)+" : " +str(cust[column].unique()))
        print(cust[column].value_counts())
        print('******************************************************************************')
        print('/n')
# Out:
# 1Gender of respondent : ['Male' 'Female']
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64
# ******************************************************************************
# /n
# 2 How old are you?  : ['31-40 years' '21-30 years' '41-50 yaers' 'Less than 20 years'
#  '51 years and above']
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64
# ******************************************************************************
# /n
# 3 Which city do you shop online from? : ['Delhi' 'Greater Noida' 'Karnal ' 'Bangalore ' 'Noida' 'Solan'
#  'Moradabad' 'Gurgaon ' 'Merrut' 'Ghaziabad' 'Bulandshahr']
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# ...

# %% [markdown]
# ### Visualization

# %%
sns.countplot(x='1Gender of respondent',data=cust,palette='cool')
plt.title('Numbers of male and female')
plt.show()
print(cust['1Gender of respondent'].value_counts())
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %% [markdown]
# ### observation:
#     1]There are 181 female online buyers and 88 men who buys online .

# %%
sns.countplot(x='3 Which city do you shop online from?',data=cust,palette='cool')
plt.title('Name of the city')
plt.show()
print(cust['3 Which city do you shop online from?'].value_counts())
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %% [markdown]
# Observtion-maximum shopping is done from Delhi and minimum shopping is done from Bulandshahr.

# %%
sns.countplot(x='4 What is the Pin Code of where you shop online from?',data=cust,palette='cool')
plt.title('Pincode of the place')
plt.show()
print(cust['4 What is the Pin Code of where you shop online from?'].value_counts())
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173212     9
# 250001     9
# 173229     9
# 560037     8
# 132036     8
# 560010     8
# 122018     8
# 110011     7
# 201306     7
# 110008     7
# 110014     6
# 110018     6
# 244001     5
# 201312     5
# 530068     5
# 201305     5
# 201009     5
# 201008     5
# 201005     4
# 201001     4
# 201304     4
# 110039     4
# 110030     4
# 110009     4
# 560018     4
# 560003     4
# 122009     4
# 560002     4
# 110042     4
# 201303     4
# 560013     3
# 203001     2
# 560001     1
# 203207     1
# 203202     1
# Name: 4 What is the Pin Code of where you shop online from?, dtype: int64

# %% [markdown]
# Obseration-maximum shopping isdonefrom the area with pincode-201308 and minimum is done from the aarea with pincode.

# %%
sns.countplot(x='5 Since How Long You are Shopping Online ?',data=cust,palette='cool')
plt.title('Cutomers Shopping period ')
plt.show()
print(cust['5 Since How Long You are Shopping Online ?'].value_counts())
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %% [markdown]
# Observation-maximum customers are consistently shopping from more than 4 years.

# %%
sns.countplot(x='6 How many times you have made an online purchase in the past 1 year?',data=cust,palette='cool')
plt.title('Cutomers online purchase')
plt.show()
print(cust['6 How many times you have made an online purchase in the past 1 year?'].value_counts())
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %% [markdown]
# Observation-maximum customers have done online purchase for less than 10 times.

# %%
sns.countplot(x='7 How do you access the internet while shopping on-line?',data=cust,palette='cool')
plt.title('Internet access type')
plt.show()
print(cust['7 How do you access the internet while shopping on-line?'].value_counts())
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %% [markdown]
# Observtion-maximum cutomers areusing mobileinternet while shopping online.

# %%
sns.countplot(x='8 Which device do you use to access the online shopping?',data=cust,palette='cool')
plt.title('Device used by customers')
plt.show()
print(cust['8 Which device do you use to access the online shopping?'].value_counts())
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %% [markdown]
# Observtion-maximum customers are using smartphones to access online shopping.

# %%
cust.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
sns.countplot(x='Longer time to get logged in (promotion, sales period)',data=cust,palette='cool')
plt.title('How much time online sites take to load')
plt.show()
print(cust['Longer time to get logged in (promotion, sales period)'].value_counts())
# Out:
# Amazon.in                                57
# Paytm.com                                38
# Amazon.in, Flipkart.com                  38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64

# %% [markdown]
# Obervtion-Amazon.in is taking maximum time to get logged in. all other sites are taking less time comparitively.Flipkart is
# taking minimum time.

# %%
sns.countplot(x='Longer time in displaying graphics and photos (promotion, sales period)',data=cust,palette='cool')
plt.title('Time taking in displaying graphics and photos')
plt.show()
print(cust['Longer time in displaying graphics and photos (promotion, sales period)'].value_counts())
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Paytm.com                              15
# Flipkart.com                           15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64

# %% [markdown]
# Observation-Amazon.in,Flipkart.com takes maximum time.all other apps are taking less time comparitively.Amazon.in,Paytm.com is
# taking minimum time.

# %%
sns.countplot(x='Late declaration of price (promotion, sales period)',data=cust,palette='cool')
plt.title('Time of declaration of price')
plt.show()
print(cust['Late declaration of price (promotion, sales period)'].value_counts())
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Flipkart.com               38
# Amazon.in                  38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %% [markdown]
# Observation-Myntra.com do very late declaration of price.All other apps do erly declaration as comparedto myntra.com.
# Amazon.in,Flipkart.com are the earliest amongst all.

# %%
sns.countplot(x='Longer page loading time (promotion, sales period)',data=cust,palette='cool')
plt.title('Page loading time')
plt.show()
print(cust['Longer page loading time (promotion, sales period)'].value_counts())
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %% [markdown]
# Observtion-Myntra.com takes longest time to load a page.all other websites/applications takes comparitively less time to a page.

# %%
sns.countplot(x='Limited mode of payment on most products (promotion, sales period)',data=cust,palette='cool')
plt.title('Modes of payment')
plt.show()
print(cust['Limited mode of payment on most products (promotion, sales period)'].value_counts())
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %% [markdown]
# Observtion-Snapdeal.com have very limited modes of payment.other wensites have comparitively more payment modes.

# %%
sns.countplot(x='Longer delivery period',data=cust,palette='cool')
plt.title('Delivery period')
plt.show()
print(cust['Longer delivery period'].value_counts())
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Myntra.com                 26
# Paytm.com, Snapdeal.com    26
# Name: Longer delivery period, dtype: int64

# %%
sns.countplot(x='Change in website/Application design',data=cust,palette='cool')
plt.title('Changein website/application design')
plt.show()
print(cust['Change in website/Application design'].value_counts())
# Out:
# Amazon.in                   96
# Paytm.com                   63
# Amazon.in, Flipkart.com     45
# Myntra.com                  30
# Flipkart.com                20
# Snapdeal.com                 8
# Flipkart.com, Myntra.com     7
# Name: Change in website/Application design, dtype: int64

# %%
sns.countplot(x='Frequent disruption when moving from one page to another',data=cust,palette='cool')
plt.title('Disruption in website')
plt.show()
print(cust['Frequent disruption when moving from one page to another'].value_counts())
# Out:
# Amazon.in                     53
# Myntra.com                    52
# Snapdeal.com                  49
# Paytm.com                     39
# Flipkart.com                  26
# Amazon.in, Flipkart.com       25
# Myntra.com, Snapdeal.com      14
# Flipkart.com, Snapdeal.com    11
# Name: Frequent disruption when moving from one page to another, dtype: int64

# %%
sns.countplot(x='Website is as efficient as before',data=cust,palette='cool')
plt.title('Efficiency of website')
plt.show()
print(cust['Website is as efficient as before'].value_counts())
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before, dtype: int64

# %%
sns.countplot(x='Which of the Indian online retailer would you recommend to a friend?',data=cust,palette='cool')
plt.title('Recommended online retailer')
plt.show()
print(cust['Which of the Indian online retailer would you recommend to a friend?'].value_counts())
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %% [markdown]
# ### Final Observation-According to the above analysis, Amazon.in and Flipkart.com give better experience to the customers for online shopping.
